# %% [markdown]
# > # Dear Epsilon Students,
# > # The More you practice The better You'll Be.

# %% [markdown]
# ## **Problem 1: Basic Arithmetic Operations**
# - Write a program that takes two integers with variables names `a` and `b`, and prints their sum, difference, multiplication, exponent, division, floor division and modulus.

# %%
# Answer here

a = int(input("Enter the first number : "))
b = int(input("Enter the second number : "))
print(f'''
The sum of {a} + {b} = {a + b}

The difference of {a} - {b} = {a - b}

The multiplication of {a} * {b} = {a * b}

The exponent of {a} ** {b} = {a ** b}

The division of {a} / {b} = {a / b}

The floor division of {a} // {b} = {a // b}

The modulus of {a} % {b} = {a % b}
''')
# Out:
# Enter the first number : 7
# Enter the second number : 3
#
# The sum of 7 + 3 = 10
#
# The difference of 7 - 3 = 4
#
# The multiplication of 7 * 3 = 21
#
# The exponent of 7 ** 3 = 343
#
# The division of 7 / 3 = 2.3333333333333335
#
# The floor division of 7 // 3 = 2
#
# The modulus of 7 % 3 = 1

# %% [markdown]
# ## **Problem 2: Basic Arithmetic Operations**
# - Given the radius of a circle, calculate circumference

# %%
radius = 5

# Answer here

import math
circumference_Of_Circle = 2 * math.pi * 5
print("The circumference is : " , circumference_Of_Circle)
# Out:
# The circumference is :  31.41592653589793

# %% [markdown]
# ## **Problem 3: Basic Arithmetic Operations**
# - Given the width and height of a rectangle, calculate the perimeter

# %%
length = 5
width = 10

# Answer here
perimeter = 2 * (length + width)
print(f'The perimeter = {perimeter}')
# Out:
# The perimeter = 30

# %% [markdown]
# ## **Problem 4: Multi-line String and Escaping Characters**
# - Write a program that prints a multi-line string that includes escaped characters like newline (\n), tab (\t), and backslash (\\).

# %%
# Answer here
print('''
This is a multi-line string that contains : \n
escaped characters like : \\n , \\t
(\\) \t shows how backslash (\\) can be printed \n

''')
# Out:
# This is a multi-line string that contains :
#
# escaped characters like : \n , \t
# (\) 	 shows how backslash (\) can be printed

# %% [markdown]
# ## **Problem 5: String Indexing**
# - Given the string 'hello' give an index command that returns 'e'

# %%
# Answer here
word = "hello"
print(word[1])
# Out:
# e

# %% [markdown]
# ## **Problem 6: String Indexing and Slicing**
# ### Write a program that takes a string `s` and prints :
# - first character
# - last character
# - Substring from (e) character to (w) character.

# %%
s = 'helloworld'

# Answer here
print(s[0] , s[-1],s[1:6])
# Out:
# h d ellow

# %% [markdown]
# ## **Problem 7: Reverse a String**
# - Reverse the string 'hello' using slicing

# %%
# Answer here
str = 'hello'
print(str[::-1])
# Out:
# olleh

# %% [markdown]
# ## **Problem 8: String Formatting**
# - Write a program that takes an integer with variable name `n` and prints a formatted string like this `The number is : 10`

# %%
# Answer here

num = int(input("Enter a number : "))
print(f'The number is : {num}')
# Out:
# Enter a number : 10
# The number is : 10

# %% [markdown]
# ## **Problem 9: String Formatting**
# - Write a program that takes a `name` and an `age` as variables and prints a formatted string "Hello, `name`! You are `age` years old."

# %%
# Answer here
name = input("Enter your name :")
age = int(input("Enter your age :"))
print(f"Hello, {name}! You are {age} years old.")
# Out:
# Enter your name :Tarneem
# Enter your age :22
# Hello, Tarneem! You are 22 years old.

# %% [markdown]
# ## **Problem 10: Built in Functions**
# - Write a program that check the data type of a given string `s`.

# %%
s = 'Hello World'

# Answer here

_type = type(s)
print(f"The type of {s} is {_type}")
# Out:
# The type of Hello World is <class 'str'>

# %% [markdown]
# - Write a program that check the data type of a given number.

# %%
n = 10

# Answer here

_type = type(n)
print(f"The type of {n} is {_type}")
# Out:
# The type of 10 is <class 'int'>

# %% [markdown]
# - Write a program that check the data type of a given number.

# %%
n = 1.5

# Answer here

_type = type(n)
print(f"The type of {n} is {_type}")
# Out:
# The type of 1.5 is <class 'float'>

# %% [markdown]
# ## **Problem 11: Built in Functions**
# - Write code that takes email and password from user and assign them to two variables

# %%
# Answer here
email = input("Enter your email :  ")
password = input("Enter your password :  ")
print(f"Your E-mail is: {email}\tPassword : {password} ")
# Out:
# Enter your email :  tarneem@123
# Enter your password :  h1485
# Your E-mail is: tarneem@123	Password : h1485

# %% [markdown]
# ## **Problem 12: Built in Functions**
# - Write a program that asks the user to enter their first and last name separately, then prints their full name on one line.

# %%
# Answer here
firstName = input("Enter your first name : ")
lastName = input("Enter your last name : ")
fullName = firstName +' '+ lastName
print(f'Your Full name is : {fullName}')
# Out:
# Enter your first name : tarneem
# Enter your last name : medhat
# Your Full name is : tarneem medhat

# %% [markdown]
# # <center> Thank you for your effort ❤️ </center>
